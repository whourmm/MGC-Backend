# %%
# install pytesseract
# %pip install opencv-python matplotlib numpy pytesseract
# Out:
# Requirement already satisfied: opencv-python in d:\4 projects\mgc\.venv\lib\site-packages (4.10.0.84)
# Requirement already satisfied: matplotlib in d:\4 projects\mgc\.venv\lib\site-packages (3.9.1.post1)
# Requirement already satisfied: numpy in d:\4 projects\mgc\.venv\lib\site-packages (2.0.1)
# Requirement already satisfied: pytesseract in d:\4 projects\mgc\.venv\lib\site-packages (0.3.10)
# Requirement already satisfied: contourpy>=1.0.1 in d:\4 projects\mgc\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\4 projects\mgc\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\4 projects\mgc\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\4 projects\mgc\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\4 projects\mgc\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\4 projects\mgc\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\4 projects\mgc\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\4 projects\mgc\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\4 projects\mgc\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# organize imports
import numpy as np
import cv2
from matplotlib import pyplot as plt
from pathlib import Path

brand_text = 'ALLERCARE'
SAMPLE_PATH = Path.cwd() / 'data' / 'real2.jpg'
img = cv2.imread(SAMPLE_PATH)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
if img.shape[0] < img.shape[1]:
    img = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    
img = cv2.resize(img, (1148, 2040))
plt.imshow(img)

# %%
edged = cv2.Canny(img, 170, 490
                      )
plt.imshow(edged)
plt.show()

# %%
# convert to grayscale
def get_device_image(img):
    edged = cv2.Canny(img, 170, 490
                      )
    plt.imshow(edged)
    plt.show()
    # sharpen the image
    # Apply adaptive threshold
    thresh = cv2.adaptiveThreshold(edged, 255, 1, 1, 11, 2)

    # apply some dilation and erosion to join the gaps - change iteration to detect more or less area's
    thresh = cv2.dilate(thresh,None,iterations = 55)
    thresh = cv2.erode(thresh,None,iterations = 55)


    # Find the contours
    contours,_ = cv2.findContours(thresh,
                                            cv2.RETR_EXTERNAL,
                                            cv2.CHAIN_APPROX_SIMPLE)
    
    # For each contour, find the bounding rectangle and draw it
    boxes = [cv2.boundingRect(cnt) for cnt in contours]
    max_box = max(boxes, key=lambda x: x[2]*x[3])
    x, y, w, h = max_box
    show_img = img[y:y+h,x:x+w, :]
        
    if w > h:
        show_img = np.rot90(show_img)
        
    plt.imshow(show_img)
    
    
    cntr = max(contours, key=cv2.contourArea)  
    peri = cv2.arcLength(cntr, True)
    approx = cv2.approxPolyDP(cntr, 0.05 * peri, True)
	# draw the approximated contour on the image
    output = img.copy()
    cv2.drawContours(output, [approx], -1, (0, 255, 0), 3)
    plt.imshow(output)
    plt.show()

    cont = np.array(approx).reshape(-1, 2)
    middle_point = np.mean(cont, axis=0)
    for c in cont:
        if c[0] < middle_point[0]:
            if c[1] < middle_point[1]:
                top_left = c
            else:
                bottom_left = c
        else:
            if c[1] < middle_point[1]:
                top_right = c
            else:
                bottom_right = c
    # find most left and right point/ top and bottom point
    

    w, h = 260, 950
    corners = np.array([top_left, top_right, bottom_left, bottom_right], dtype = np.float32)
    transformed_shape = np.array([[0, 0], [w, 0], [0, h],[w, h]], dtype = np.float32)
    perspective_transform = cv2.getPerspectiveTransform(corners,transformed_shape)
    img_Output = cv2.warpPerspective(img,perspective_transform,(w, h))
    plt.imshow(img_Output)
    plt.show()

    top = int(0.25 * h)
    bottom = int(0.83 * h)
    num = 5

    device = img_Output[top:bottom, ...].copy()
    
    fig, axs = plt.subplots(1, num, figsize=(10, 10))
    
    strip_height = (bottom - top) // num
    strips_img = []
    for i, ax in enumerate(axs):
        strip = device[i*strip_height:(i+1)*strip_height, ...]
        strips_img.append(strip)
        ax.imshow(strip)
    plt.show()
    return strips_img

# %%
def enhance_image(img):
    lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l_channel, a, b = cv2.split(lab)

    # Applying CLAHE to L-channel
    # feel free to try different values for the limit and grid size:
    clahe = cv2.createCLAHE(clipLimit=16.0, tileGridSize=(16,16))
    cl = clahe.apply(l_channel)

    # merge the CLAHE enhanced L-channel with the a and b channel
    limg = cv2.merge((cl,a,b))
    enhanced_img = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return enhanced_img

def get_line(ori_strip):
    ori_strip = ori_strip[:, ori_strip.shape[1]//3:(ori_strip.shape[1]* 2) //3, :]
    ori_strip = cv2.fastNlMeansDenoisingColored(ori_strip, None, 10, 10, 2, 3) 

    strip = enhance_image(ori_strip)
    strip = cv2.cvtColor(ori_strip, cv2.COLOR_RGB2GRAY)
    # adaptive thresholding
    strip = cv2.adaptiveThreshold(strip, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 63, 31)
    # otsu binarization
    # strip = cv2.threshold(strip, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
    # apply some dilation and erosion to join the gaps - change iteration to detect more or less area's
    # apply morphology open with square kernel to remove small white spots
    plt.imshow(strip)
    plt.show()
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
    strip = cv2.morphologyEx(strip, cv2.MORPH_OPEN, kernel)

    # apply morphology close with horizontal rectangle kernel to fill horizontal gap
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
    strip = cv2.morphologyEx(strip, cv2.MORPH_CLOSE, kernel)

    plt.imshow(strip)
    plt.show()
    # not operation
    strip = cv2.bitwise_not(strip)
    
    # Find the contours
    contours,_ = cv2.findContours(strip,
                                            cv2.RETR_TREE,
                                            cv2.CHAIN_APPROX_SIMPLE,
    )

    x_offset = 2
    y_offset = 1
    # For each contour, find the bounding rectangle and draw it
    color_lines = []
    for cnt in contours:
        x,y,w,h = cv2.boundingRect(cnt)
        color_line = ori_strip[max(0, y - y_offset):min(ori_strip.shape[0],y + h + y_offset), max(x - x_offset , 0): min(ori_strip.shape[1], x + w + x_offset)]
        color_lines.append([color_line, np.array([x,y,w,h])])

    # merge line that have same height with other line

    # color_lines = sorted(color_lines, key=lambda x: x[1][1])
    # for i in range(len(color_lines) - 1):
    #     if color_lines[i + 1][1][1] - color_lines[i][1][1] < color_lines[i][1][3] // 5:
    #         x,y,w,h = color_lines[i][1]
    #         x1,y1,w1,h1 = color_lines[i + 1][1]
    #         color_line = ori_strip[max(0, y - y_offset, y1 - y_offset):min(ori_strip.shape[0],y + h + y_offset, y1 + h1 + y_offset), max(x - x_offset , 0): min(ori_strip.shape[1], x + w + x_offset, x1 + w1 + x_offset)]
    #         color_lines[i + 1] = [color_line, np.array([min(x, x1), min(y, y1), max(x + w, x1 + w1) - min(x, x1), max(y + h, y1 + h1) - min(y, y1)])]
    #         color_lines[i] = None
    # # delete
    # for i in range(len(color_lines) - 1, -1, -1):
    #     if color_lines[i] is None:
    #         color_lines.pop(i)
    
    if len(color_lines) == 2: # only get 2 lines then it is missing the middle line
        x,y,w,h = (color_lines[0][1] + color_lines[1][1]) // 2
        color_line = ori_strip[max(0, y - y_offset):min(ori_strip.shape[0],y + h + y_offset), max(x - x_offset , 0): min(ori_strip.shape[1], x + w + x_offset)]
        color_lines.insert(1, [color_line, np.array([x,y,w,h])])
    elif len(color_lines) > 3:
        areas = [line[1][2] * line[1][3] for line in color_lines]
        idx = sorted(np.argsort(areas)[::-1][:3])
        color_lines = [color_lines[i] for i in idx]
    
    for line in color_lines:
        plt.imshow(line[0])
        plt.show()
    for _, box in color_lines:
        x,y,w,h = box
        cv2.rectangle(ori_strip, (x, y), (x + w, y + h), (0, 255, 0), 2)
    plt.imshow(ori_strip)
    plt.show()
    # print(len(color_lines))
    return [line[0] for line in color_lines]

# %%
def get_lightness(color):
    return 0.2 * color[0] + 0.2 * color[1] + 0.7 * color[2]
def get_approx_colors(color_lines):
    fig, axs = plt.subplots(1, 3, figsize=(10, 10))
    average_colors = []
    for i,color_strip in enumerate(color_lines):
        # get weights average of top 10 color
        color_strip = color_strip.reshape(-1, 3)
        # count the color using np.unique
        color_strip_filtered = color_strip[color_strip[:, 2] < 190] # remove white-blue color
        if len(color_strip_filtered) <= 3:
            average_colors.append(min(color_strip, key=lambda x: get_lightness(x)))
        else:
            color, count = np.unique(color_strip_filtered, axis=0, return_counts=True)

            # get the top 10 color
            top_color = np.argsort(count)[::-1][:3]
            weights = count[top_color]
            top_color = color[top_color]
            # get the average color
            average_color = np.average(top_color, axis=0, weights=weights)
            average_colors.append(average_color)
            axs[i].imshow(average_color.astype(np.uint8).reshape(1, 1, 3))
    plt.show()
    return average_colors

# %%
def rgb_projection_distance(average_colors):
    average_colors = 1 - np.array(average_colors) / 255
    
    measure_vector = average_colors[1] - average_colors[0]
    scale_vector = average_colors[2] - average_colors[0]
    measurement_scale = np.dot(scale_vector, measure_vector) / np.linalg.norm(scale_vector) ** 2 # projection of measure_vector to scale_vector then inverse it to get the scale
    print(f'{measurement_scale=}')
    return measurement_scale

def rgb_distance(average_colors):
    average_colors = 1 - np.array(average_colors) / 255
    
    measure_vector = average_colors[1] - average_colors[0]
    scale_vector = average_colors[2] - average_colors[0]
    measurement_scale = np.linalg.norm(measure_vector) / np.linalg.norm(scale_vector)
    # print(f'{measurement_scale=}')
    return measurement_scale

# %%
def run_process(img):
    measurements = []
    strips_img = get_device_image(img)[::-1]
    for i,strip in enumerate(strips_img, start = 1):
        color_lines = get_line(strip)
        average_colors = get_approx_colors(color_lines)
        measure = rgb_projection_distance(average_colors)
        print(f'{i}\'s strip: {measure:.3f}')
        if measure < 0.2:
           measure = 1
        elif measure < 0.4:
           measure = 2
        elif measure < 0.6:
           measure = 3
        elif measure < 0.8:
           measure = 4
        else:
           measure = 5
        measurements.append(measure)
    
    return measurements

# %%
def main(img):
    try:
        return run_process(img)
    except Exception as e:
        # 180 degree rotation
        img = cv2.rotate(img, cv2.ROTATE_180)
        return run_process(img)

# %%
run_process(img)
# Out:
# measurement_scale=np.float64(3.0899094838753673)
# 1's strip: 3.090
# measurement_scale=np.float64(1.7105318811585846)
# 2's strip: 1.711
# measurement_scale=np.float64(-7.319370536879032)
# 3's strip: -7.319
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[459], line 1
# ----> 1 run_process(img)
#
# Cell In[457], line 7, in run_process(img)
#       5 color_lines = get_line(strip)
#       6 average_colors = get_approx_colors(color_lines)
# ----> 7 measure = rgb_projection_distance(average_colors)
#       8 print(f'{i}\'s strip: {measure:.3f}')
#       9 if measure < 0.2:
#
# Cell In[456], line 4, in rgb_projection_distance(average_colors)
#       1 def rgb_projection_distance(average_colors):
#       2     average_colors = 1 - np.array(average_colors) / 255
# ----> 4     measure_vector = average_colors[1] - average_colors[0]
#       5     scale_vector = average_colors[2] - average_colors[0]
#       6     measurement_scale = np.dot(scale_vector, measure_vector) / np.linalg.norm(scale_vector) ** 2 # projection of measure_vector to scale_vector then inverse it to get the scale
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
